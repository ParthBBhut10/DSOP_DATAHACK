# %%
import pandas as pd
import numpy as np

# %%
video = pd.read_csv("/content/dataset_datahack_videos.csv")

# %%
channel = pd.read_csv("/content/dataset_datahack_channels.csv")

# %%
channel.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                channel_id       channel_title  \
# 0             0           0  UCn_l37ETRGxVsVqPAZM-y7w             Onkiify
# 1             1           1  UCg3811K2k6ZW0T9wrUyq7UQ  Boyzz World Gaming
# 2             2           2  UCO1-i4iqe_Kg0B-nwt5W0Gg        Majnu Gaming
# 3             3           3  UC6AhmVhClcDx2RPsFFw_fAA            SELEM YT
# 4             4           4  UC5v-gTzCpaY257sxx-8P_-Q         Paglaa Tech
#
#                                          description  view_count  \
# 0  Ahoy! Gamers What is Up it's your Boi Onkiify....     1443714
# 1  Sup Guys\n                 I'm just a Weirdo W...      761326
# 2  Hello Gamer's 😍\n\nHello Family, \nMera Name H...      290799
# 3  \nAGAR AAP LOG FREE FIRE LOVER❤️ HO TO MERA CH...     6427859
# 4  1000 subscribers - 31/12/2021\n10000 subscribe...    17097445
#
#    subscriber_count  video_count                 created_time  \
# 0              4820          193         2017-05-18T17:27:05Z
# ...

# %%
video
# Out:
#      Unnamed: 0.1  Unnamed: 0  index     video_id  \
# 0               0           0      0  -gJ1a4qzO58
# 1               1           1      2  XbIegQ5v334
# 2               2           2      5  bTo4s27L1Uw
# 3               3           3      6  iEtjePI_sqc
# 4               4           4      8  gSYT7WSfekk
# ..            ...         ...    ...          ...
# 466           466         466    742  r6C1nf_iz3o
# 467           467         467    743  515fPTbB-2o
# 468           468         468    745  rJd57wSoxs8
# 469           469         469    747  sVte67QEAvU
# 470           470         470    748  yV49JQ7d6-4
#
#                                                  title  \
# 0    Adopted by the SMALLEST FAMILY in Minecraft! (...
# 1    I started playing chess when I was three years...
# 2    #1 How @BBKiVines become 1 of India’s RICHEST ...
# 3                           Mere paas SABOOT nahi hai!
# 4    The BIRTH to DEATH of a Minecraft ELEPHANT! 😱 ...
# ...

# %%
len(channel)
# Out:
# 50

# %%
# a=video.sort_values(by='view_count',ascending=0)
# a = df.sort_values(by ='Science', ascending = 0)

# %%
# b=video.sort_values(by ='likes', ascending = 0)

# %%
c= channel.sort_values(by ='subscriber_count', ascending = 0)

# %%
c.head(31)
# 260787957
# Out:
#     Unnamed: 0.1  Unnamed: 0                channel_id  \
# 26            26          26  UCwAdQUuPT6laN-AQR17fe1g
# 25            25          25  UCe3qdG0A_gr-sEdat5y2twQ
# 14            14          14  UC1_-cyLlwnmTAesbMgruDpQ
# 33            33          33  UCNn6AaHharXIbkRleXGboiQ
# 39            39          39  UCfhbydY40P2Lli9HuBz8cdA
# 47            47          47  UChZ0JmGgyOWSU-1iXxPhsVA
# 37            37          37  UCzgCuuPQa1nMlZP9ruPYDNw
# 22            22          22  UCRzYN32xtBf3Yxsx5BvJWJw
# 43            43          43  UCYLS9TSah19IsB8yyUpiDzg
# 7              7           7  UC2IuURiiASwNigfQJtXiRdQ
# 5              5           5  UCHOrSFKttbAKpcyjnBfVqkw
# 19            19          19  UCE_uu-BpfKPx8a-sjwBy-rA
# 40            40          40  UCWZtQWpe1C2AksuJ5_eCMAQ
# 27            27          27  UCwVEhEzsjLym_u1he4XWFkg
# 23            23          23  UCWP4FTfQYQ5kaNzfUaiZT9A
# 48            48          48  UC8mlgT6I0aSexwFPsOgMG_g
# ...

# %%
channel.sort_values(by = 'view_count',ascending=0).head(31)
# Out:
#     Unnamed: 0.1  Unnamed: 0                channel_id  \
# 47            47          47  UChZ0JmGgyOWSU-1iXxPhsVA
# 33            33          33  UCNn6AaHharXIbkRleXGboiQ
# 36            36          36  UCIsEhwBMPkRHsEgqYAPQHsA
# 43            43          43  UCYLS9TSah19IsB8yyUpiDzg
# 14            14          14  UC1_-cyLlwnmTAesbMgruDpQ
# 40            40          40  UCWZtQWpe1C2AksuJ5_eCMAQ
# 27            27          27  UCwVEhEzsjLym_u1he4XWFkg
# 41            41          41  UC7adUjW8qMUsqO4HHTbwKgg
# 26            26          26  UCwAdQUuPT6laN-AQR17fe1g
# 19            19          19  UCE_uu-BpfKPx8a-sjwBy-rA
# 45            45          45  UCAov2BBv1ZJav0c_yHEciAw
# 23            23          23  UCWP4FTfQYQ5kaNzfUaiZT9A
# 34            34          34  UCqgdGSJPEKCGwElnwnKGE6Q
# 39            39          39  UCfhbydY40P2Lli9HuBz8cdA
# 17            17          17  UCJihyK0A38SZ6SdJirEdIOw
# 7              7           7  UC2IuURiiASwNigfQJtXiRdQ
# ...

# %%
# /Channel Title: Name of the channel as visible on YouTube

# %%
channel[channel.view_count>=24390585].sort_values('subscriber_count', ascending = False)[10:20]
# Out:
#     Unnamed: 0.1  Unnamed: 0                channel_id  \
# 5              5           5  UCHOrSFKttbAKpcyjnBfVqkw
# 19            19          19  UCE_uu-BpfKPx8a-sjwBy-rA
# 40            40          40  UCWZtQWpe1C2AksuJ5_eCMAQ
# 27            27          27  UCwVEhEzsjLym_u1he4XWFkg
# 23            23          23  UCWP4FTfQYQ5kaNzfUaiZT9A
# 48            48          48  UC8mlgT6I0aSexwFPsOgMG_g
# 17            17          17  UCJihyK0A38SZ6SdJirEdIOw
# 41            41          41  UC7adUjW8qMUsqO4HHTbwKgg
# 49            49          49  UCM-yUTYGmrNvKOCcAl21g3w
# 36            36          36  UCIsEhwBMPkRHsEgqYAPQHsA
#
#              channel_title                                        description  \
# 5            Prabhat Gamer  Hi guys I am Prabhat from Uttarakhand❤️\n🎬This...
# 19             Rajat Arora  We will make sure to let you learn everything ...
# 40                Neon Man  Welcome to India's #1 YouTube News Channel!\n\...
# ...

# %%
# s2=pd.merge(c, d, how='inner', on=['channel_title'])

# %%
# s2.head()

# %%
# s1.head()

# %%
from textblob import TextBlob
TextBlob('Minecraft aacha hai').sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
from textblob import TextBlob
a,b=TextBlob('Manager never').sentiment

# %%
a
# Out:
# 0.0

# %%
pip install google_trans_new
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from numpy.core.multiarray import zeros
b=[]
from google_trans_new import google_translator

translator = google_translator()

for j in range(len(video)):
  a=list(video.Comments[j])
  a= ''.join(a)
  li = list(a.split(","))
  z=0
  for i in range(len(li)):

    thisdict=classifier(li[i])
    # x = thisdict["label"]
    # y=thisdict["score"]
    if thisdict[1]=="NEGATIVE":
    #   z=z-score
    # else:
    #   z=z+score
      print(thisdict[-1])

  b.append(int(z))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-147-f214c768e397> in <cell line: 7>()
#      15     # x = thisdict["label"]
#      16     # y=thisdict["score"]
# ---> 17     if thisdict[1]=="NEGATIVE":
#      18     #   z=z-score
#      19     # else:
#
# IndexError: list index out of range

# %%
# #sample code 
# !pip install transformers
# from transformers import BertTokenizer, BertForSequenceClassification
# tokenizerg = BertTokenizer.from_pretrained("/content/model")
# modelg = BertForSequenceClassification.from_pretrained("/content/model")

# text = "kuch bhi type karo hinglish mai"
# encoded_input = tokenizerg(text, return_tensors='pt')
# output = modelg(**encoded_input)
# print(output)

# %%
>>> from transformers import pipeline

# Allocate a pipeline for sentiment-analysis
>>> classifier = pipeline('sentiment-analysis')
>>> classifier('hum dkhi hai.')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'NEGATIVE', 'score': 0.54730224609375}]

# %%
gk-hinglish-sentiment

# %%
b
