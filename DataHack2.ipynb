# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import string
import nltk
import csv

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
  # Load data on video views, likes, and shares
  channel = pd.read_csv("/content/dataset_datahack_channels.csv")
  video = pd.read_csv("/content/dataset_datahack_videos.csv")

# %%
video['title'] = video['title'].str.lower()
video['description'] = video['description'].str.lower()
video['tags'] = video['tags'].str.lower()
video['Comments'] = video['Comments'].str.lower()
video
# Out:
#      Unnamed: 0.1  Unnamed: 0  index     video_id  \
# 0               0           0      0  -gJ1a4qzO58
# 1               1           1      2  XbIegQ5v334
# 2               2           2      5  bTo4s27L1Uw
# 3               3           3      6  iEtjePI_sqc
# 4               4           4      8  gSYT7WSfekk
# ..            ...         ...    ...          ...
# 466           466         466    742  r6C1nf_iz3o
# 467           467         467    743  515fPTbB-2o
# 468           468         468    745  rJd57wSoxs8
# 469           469         469    747  sVte67QEAvU
# 470           470         470    748  yV49JQ7d6-4
#
#                                                  title  \
# 0    adopted by the smallest family in minecraft! (...
# 1    i started playing chess when i was three years...
# 2    #1 how @bbkivines become 1 of india’s richest ...
# 3                           mere paas saboot nahi hai!
# 4    the birth to death of a minecraft elephant! 😱 ...
# ...

# %%
def clean_text(text):
  for char in text:
    if char in string.punctuation:
      text = text.replace(char,'')
  return text

# %%
video['title'] = video['title'].apply(lambda x:clean_text(x))
#video['description'] = video['description'].apply(lambda x:clean_text(x))
video['tags'] = video['tags'].apply(lambda x:clean_text(x))
video['Comments'] = video['Comments'].apply(lambda x:clean_text(x))
video
# Out:
#      Unnamed: 0.1  Unnamed: 0  index     video_id  \
# 0               0           0      0  -gJ1a4qzO58
# 1               1           1      2  XbIegQ5v334
# 2               2           2      5  bTo4s27L1Uw
# 3               3           3      6  iEtjePI_sqc
# 4               4           4      8  gSYT7WSfekk
# ..            ...         ...    ...          ...
# 466           466         466    742  r6C1nf_iz3o
# 467           467         467    743  515fPTbB-2o
# 468           468         468    745  rJd57wSoxs8
# 469           469         469    747  sVte67QEAvU
# 470           470         470    748  yV49JQ7d6-4
#
#                                                  title  \
# 0    adopted by the smallest family in minecraft hindi
# 1    i started playing chess when i was three years...
# 2    1 how bbkivines become 1 of india’s richest yo...
# 3                            mere paas saboot nahi hai
# 4    the birth to death of a minecraft elephant 😱 h...
# ...

# %%
video['title'] = video['title'].str.strip()
video['description'] = video['description'].str.strip()
video['tags'] = video['tags'].str.strip()
video['Comments']=video['Comments'].str.strip()
video
# Out:
#      Unnamed: 0.1  Unnamed: 0  index     video_id  \
# 0               0           0      0  -gJ1a4qzO58
# 1               1           1      2  XbIegQ5v334
# 2               2           2      5  bTo4s27L1Uw
# 3               3           3      6  iEtjePI_sqc
# 4               4           4      8  gSYT7WSfekk
# ..            ...         ...    ...          ...
# 466           466         466    742  r6C1nf_iz3o
# 467           467         467    743  515fPTbB-2o
# 468           468         468    745  rJd57wSoxs8
# 469           469         469    747  sVte67QEAvU
# 470           470         470    748  yV49JQ7d6-4
#
#                                                  title  \
# 0    adopted by the smallest family in minecraft hindi
# 1    i started playing chess when i was three years...
# 2    1 how bbkivines become 1 of india’s richest yo...
# 3                            mere paas saboot nahi hai
# 4    the birth to death of a minecraft elephant 😱 h...
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
video['title'] = video['title'].str.replace('\d+', '')
video['description'] = video['description'].str.replace('\d+', '')
video['tags'] = video['tags'].str.replace('\d+', '')
video['Comments'] = video['Comments'].str.replace('\d+', '')
video
# Out:
# <ipython-input-215-1aa4598fd2c6>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   video['title'] = video['title'].str.replace('\d+', '')
# <ipython-input-215-1aa4598fd2c6>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   video['description'] = video['description'].str.replace('\d+', '')
# <ipython-input-215-1aa4598fd2c6>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   video['tags'] = video['tags'].str.replace('\d+', '')
# <ipython-input-215-1aa4598fd2c6>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   video['Comments'] = video['Comments'].str.replace('\d+', '')
#      Unnamed: 0.1  Unnamed: 0  index     video_id  \
# 0               0           0      0  -gJ1a4qzO58
# 1               1           1      2  XbIegQ5v334
# 2               2           2      5  bTo4s27L1Uw
# ...

# %%
video['title'].to_string
video['description'].to_string
video['Comments'].to_string
video['tags'].to_string
# Out:
# <bound method Series.to_string of 0      minecraft yes smarty pie himlands adopted by t...
# 1      chessbaseindia interviews chesstraining improv...
# 2      seeken zeeshan shaikh booming digital stars ma...
# 3      sambhavnaseth ss vlogs hindi vlogger celebrity...
# 4      minecraft yessmartypie himlands the birth to d...
#                              ...
# 466    finladder ishaan arora tedx ishaan arora ishaa...
# 467    warikoo ankur warikoo ankur warikoo motivation...
# 468    ca rachana ranade stock market basics basics o...
# 469    sambhavnaseth ss vlogs hindi vlogger celebrity...
# 470    new state mobile one plus one plus dominate on...
# Name: tags, Length: 471, dtype: object>

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# %%
a = video['title'].to_string()
a = a.split()
b = video['description'].to_string()
b = b.split()
c = video['tags'].to_string()
c = c.split()
d = video['Comments'].to_string()
d = d.split()

# %%
video['Keywords Titles'  ] = ''
for i in range(len(video['title'])):
  a = video['title'][i]
  a = a.split()
  video['Keywords Titles'][i] = a
# Out:
# <ipython-input-220-6b07d06d5ce4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   video['Keywords Titles'][i] = a

# %%
a
# Out:
# ['dominate', 'with', 'oneplus', 'r', 'g']

# %%
video['Keyword Tags'] = ''
for i in range(len(video['tags'])):
  b = video['tags'][i]
  b = b.split()
  video['Keyword Tags'][i] = b
# Out:
# <ipython-input-222-13047fe1af6e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   video['Keyword Tags'][i] = b

# %%
video['Keyword Comments'] = ''
for i in range(len(video['Comments'])):
  c = video['Comments'][i]
  c = c.split()
  video['Keyword Comments'][i] = c
# Out:
# <ipython-input-223-04025909f669>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   video['Keyword Comments'][i] = c

# %%
video['Common Title'] = ''
video['Common Description'] = ''
video['Common Tags'] = ''

video
# Out:
#      Unnamed: 0.1  Unnamed: 0  index     video_id  \
# 0               0           0      0  -gJ1a4qzO58
# 1               1           1      2  XbIegQ5v334
# 2               2           2      5  bTo4s27L1Uw
# 3               3           3      6  iEtjePI_sqc
# 4               4           4      8  gSYT7WSfekk
# ..            ...         ...    ...          ...
# 466           466         466    742  r6C1nf_iz3o
# 467           467         467    743  515fPTbB-2o
# 468           468         468    745  rJd57wSoxs8
# 469           469         469    747  sVte67QEAvU
# 470           470         470    748  yV49JQ7d6-4
#
#                                                  title  \
# 0    adopted by the smallest family in minecraft hindi
# 1    i started playing chess when i was three years...
# 2     how bbkivines become  of india’s richest yout...
# 3                            mere paas saboot nahi hai
# 4    the birth to death of a minecraft elephant 😱 h...
# ...

# %%
from collections import Counter

video['title']
# Define the number of top words to show
top_n = 5

# Create a Counter object to count the occurrence of each word
word_counts = Counter()

for sentence in video['title']:
    # Split the sentence into words
    words = sentence.split()
    # Update the word_counts with the occurrence of each word in the sentence
    word_counts.update(words)

# Get the top n most common words and their frequencies
top_words = word_counts.most_common(top_n)

print(f"Top {top_n} most frequent words in the dataset:")
for word, frequency in top_words:
    print(f"'{word}': {frequency} occurrences")
# Out:
# Top 5 most frequent words in the dataset:
# 'in': 79 occurrences
# 'to': 56 occurrences
# 'for': 51 occurrences
# 'shorts': 50 occurrences
# 'the': 46 occurrences

# %%
from collections import Counter

video['tags']
# Define the number of top words to show
top_n = 5

# Create a Counter object to count the occurrence of each word
word_counts = Counter()

for sentence in video['tags']:
    # Split the sentence into words
    words = sentence.split()
    # Update the word_counts with the occurrence of each word in the sentence
    word_counts.update(words)

# Get the top n most common words and their frequencies
top_words = word_counts.most_common(top_n)

print(f"Top {top_n} most frequent words in the dataset:")
for word, frequency in top_words:
    print(f"'{word}': {frequency} occurrences")
# Out:
# Top 5 most frequent words in the dataset:
# 'in': 380 occurrences
# 'video': 320 occurrences
# 'fire': 307 occurrences
# 'free': 304 occurrences
# 'shorts': 258 occurrences

# %%
from collections import Counter

video['Comments']
# Define the number of top words to show
top_n = 5

# Create a Counter object to count the occurrence of each word
word_counts = Counter()

for sentence in video['Comments']:
    # Split the sentence into words
    words = sentence.split()
    # Update the word_counts with the occurrence of each word in the sentence
    word_counts.update(words)

# Get the top n most common words and their frequencies
top_words = word_counts.most_common(top_n)

print(f"Top {top_n} most frequent words in the dataset:")
for word, frequency in top_words:
    print(f"'{word}': {frequency} occurrences")
# Out:
# Top 5 most frequent words in the dataset:
# 'the': 6340 occurrences
# 'and': 6003 occurrences
# 'to': 5907 occurrences
# 'you': 5809 occurrences
# 'i': 4977 occurrences
